# %% [markdown]
# <a href="https://colab.research.google.com/github/csanny/DL_NLP_101/blob/main/predict.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install numpy==1.22.2
# !pip install pandas==1.4.4
# !pip install NERDA==0.9.6
# !pip install torch==1.13.1

import numpy as np
import pandas as pd 
from NERDA.models import NERDA
import torch
import os
from google.colab import drive
import nltk
nltk.download('punkt')
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
drive.mount('/content/drive/')

# %%
model = torch.load('/content/drive/MyDrive/Colab Notebooks/Github/Survice-BERT/model/Survice-BERT_V1_32-32.pt')
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:299: UserWarning: Trying to unpickle estimator LabelEncoder from version 0.24.2 when using version 1.2.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
sentence1 = 'During the period 12 January to 15 March 2022, a total of 53 suspected yellow fever cases, including six deaths, have been reported from Isiolo county, central Kenya.'

# %%
predict_result = model.predict_text(sentence1)
pd.DataFrame({'ner':predict_result[1][0] ,'value':predict_result[0][0]})
# Out:
#              ner      value
# 0              O     During
# 1              O        the
# 2              O     period
# 3     B-DATE_DAY         12
# 4   B-DATE_MONTH    January
# 5              O         to
# 6     B-DATE_DAY         15
# 7   B-DATE_MONTH      March
# 8    B-DATE_YEAR       2022
# 9              O          ,
# 10             O          a
# 11             O      total
# 12             O         of
# 13        B-CASE         53
# 14             O  suspected
# 15     B-DISEASE     yellow
# 16     I-DISEASE      fever
# 17             O      cases
# 18             O          ,
# 19             O  including
# 20       B-DEATH        six
# 21             O     deaths
# 22             O          ,
# 23             O       have
# 24             O       been
# 25             O   reported
# 26             O       from
# 27         B-LOC     Isiolo
# 28         I-LOC     county
# 29         I-LOC          ,
# 30         B-LOC    central
# 31         I-LOC      Kenya
# ...

# %%
sentence2 = 'From 1 November 2022 to 27 January 2023, a total of 559 cases of meningitis (of which 111 are laboratory confirmed), including 18 deaths (overall CFR 3.2%), have been reported from Zinder Region, southeast of Niger, compared to the 231 cases reported during 1 November 2021 to 31 January 2022.'

# %%
predict_result = model.predict_text(sentence2)
pd.DataFrame({'ner':predict_result[1][0] ,'value':predict_result[0][0]})
# Out:
#              ner     value
# 0              O      From
# 1     B-DATE_DAY         1
# 2   B-DATE_MONTH  November
# 3    B-DATE_YEAR      2022
# 4              O        to
# ..           ...       ...
# 56             O        to
# 57    B-DATE_DAY        31
# 58  B-DATE_MONTH   January
# 59   B-DATE_YEAR      2022
# 60             O         .
#
# [61 rows x 2 columns]
